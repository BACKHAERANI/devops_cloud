# %%
import os
os.environ["DJANGO_SETTINGS_MODULE"] = "mydjango15.settings"
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

import django
django.setup()

# %%
from openpyxl import load_workbook
wb = load_workbook('mydjango15-data.xlsx')
sheet = wb.active
rows = [
    [column.value for column in row]
    for row in sheet
]
rows
# Out:
# [['name', 'description', 'address', 'coordinates', 'telephone'],
#  ['선화별당',
#   '1942년에 지어진 건물을 리모델링하여 전국 양조장에서 프리미엄 막걸리를 공급받아 판매하는 곳',
#   '대전 중구 선화서로 49-1',
#   '36.3278906,127.4177686',
#   '042-226-2010'],
#  ['보문산호랭이',
#   '인스타감성이 낭낭하면서 맛 또한 감성적인 식당',
#   '대전 중구 중교로 84-1',
#   '36.3268776,127.4287748',
#   '0507-1389-1596'],
#  ['홍콩구락부',
#   '동양과 서양의 문화가 공존하는 홍콩스타일의 무드의 요리를 선보이는 곳',
#   '대전 중구 중앙로112번길 23 ',
#   '36.3263502,127.4231139',
#   '0507-1444-6567'],
#  ['스테이블',
#   '브런치와 카페를 동시에. 배달, 포장 가능',
#   '대전 중구 중교로 41',
#   '36.3256091,127.4243679',
#   '0507-1442-2261'],
#  ['앤더즌',
#   '당일 새벽부터 만드는 신선한 도넛\n브리오슈 반죽으로 쨈도 수제로 만드는 정성스러운 도넛',
#   '대전 중구 대흥로111번길 30-13',
#   '36.3247366,127.4245381',
#   '0507-1343-9697'],
#  ['땡큐베리머치',
#   '매장에서 만드는 수제 케이크/디저트를 매일 다른 종류로 준비하는 카페\n생크림은 프랑스산 동물성 생크림을 사용하여 풍미가 좋다',
#   '대전 중구 중교로 49',
#   '36.3259473,127.425174',
#   '070-7723-0905'],
#  ['카페인히얼',
#   '대흥동 이안과 병원 1층 카페, 이용시 주차 2시간 무료',
#   '대전 중구 대종로 468 ',
#   '36.3262792,127.427652',
#   '042-300-2877'],
#  ['페이크',
#   '다양한 색감을 조화롭게 구성한 세련된 인테리어를 추구하는 카페',
#   '대전 중구 중교로 30 승촌빌딩',
#   '36.3248783,127.4232662',
#   '0507-1435-8932'],
#  ['모모제인',
#   '대전 평생학습관과 대전여중 옆 골목에 위치한 카페 ',
#   '대전 중구 대흥로121번길 30-8 1층',
#   '36.3248203,127.4254518',
#   '042-221-8321'],
#  ['카페그려',
#   '그림그리는 카페\n노키즈존',
#   '대전 중구 대흥로121번길 30-3 2층',
#   '36.3249709,127.425277',
#   '070-7799-6260'],
#  ['카페모먼트',
#   '반려동물 동반 가능 카페',
#   '대전 중구 보문로230번길 58 1층 카페모먼트',
#   '36.3240225,127.4259823',
#   '0507-1352-3304'],
#  ['어도비하우스',
#   '옛날 주택을 개조해서 만든 카페',
#   '대전 중구 대흥로169번길 15',
#   '36.3257427,127.4302365',
#   '010-9766-1321'],
#  ['하이드아웃',
#   '대전 티라미슈 찐맛집 *해란추천맛집',
#   '대전 중구 대흥로121번길 17 cafe hide out',
#   '36.3242906,127.4251327',
#   '042-253-0913'],
#  ['카페캠페인',
#   '인테리어가 예쁘고 깨끗한 카페',
#   '대전 중구 대흥로169번길 39 2층',
#   '36.3267222,127.4296469',
#   '042-8888-8888'],
#  ['카페크러쉬온드 대흥점',
#   '체인점, 둔산점도 있다',
#   '대전 중구 중앙로130번길 14 1층, 2층',
#   '36.3273534,127.4244576',
#   '0507-1327-4453'],
#  ['카페미넷',
#   '프랑스 시골의 작은 가정집에 와 있는 듯한 따뜻한 공간',
#   '대전 중구 대흥로121번길 17-1',
#   '36.3242125,127.4250075',
#   '0507-1496-7791'],
#  ['머스탱',
#   '페퍼로니 피자가 맛있는 맥주집',
#   '대전 중구 중교로 53',
#   '36.3260652,127.4255162',
#   '0507-1494-2230'],
#  ['열개의테이블',
#   '대전이색데이트 분위기좋은 텐테이블에서 칵테일',
#   '대전 중구 중교로 47',
#   '36.3258172,127.4249043',
#   '042-256-1033'],
#  ['낭만집',
#   '퓨전한식 안주와 뉴트로감성의 인테리어 \n이루어 말할수 없는 맛있는안주들이 있는 낭만집',
#   '대전 중구 중앙로122번길 45 2층',
#   '36.3258328,127.4245968',
#   '042-221-1089']]

# %%
column_names = rows[0]
column_names
# Out:
# ['name', 'description', 'address', 'coordinates', 'telephone']

# %%
row_list = []

for row in rows[1:]:
    if row[0] is None:
        break

for row in rows[1:]:
    row_dict = dict(zip(column_names, row))
    print(row_dict)
    latitude,longitude = row_dict["coordinates"].split(",")
    row_dict["latitude"] = latitude
    row_dict["longitude"] = longitude
    del row_dict["coordinates"]
    row_list.append(row_dict)

row_list
# Out:
# {'name': '선화별당', 'description': '1942년에 지어진 건물을 리모델링하여 전국 양조장에서 프리미엄 막걸리를 공급받아 판매하는 곳', 'address': '대전 중구 선화서로 49-1', 'coordinates': '36.3278906,127.4177686', 'telephone': '042-226-2010'}
# {'name': '보문산호랭이', 'description': '인스타감성이 낭낭하면서 맛 또한 감성적인 식당', 'address': '대전 중구 중교로 84-1', 'coordinates': '36.3268776,127.4287748', 'telephone': '0507-1389-1596'}
# {'name': '홍콩구락부', 'description': '동양과 서양의 문화가 공존하는 홍콩스타일의 무드의 요리를 선보이는 곳', 'address': '대전 중구 중앙로112번길 23 ', 'coordinates': '36.3263502,127.4231139', 'telephone': '0507-1444-6567'}
# {'name': '스테이블', 'description': '브런치와 카페를 동시에. 배달, 포장 가능', 'address': '대전 중구 중교로 41', 'coordinates': '36.3256091,127.4243679', 'telephone': '0507-1442-2261'}
# {'name': '앤더즌', 'description': '당일 새벽부터 만드는 신선한 도넛\n브리오슈 반죽으로 쨈도 수제로 만드는 정성스러운 도넛', 'address': '대전 중구 대흥로111번길 30-13', 'coordinates': '36.3247366,127.4245381', 'telephone': '0507-1343-9697'}
# {'name': '땡큐베리머치', 'description': '매장에서 만드는 수제 케이크/디저트를 매일 다른 종류로 준비하는 카페\n생크림은 프랑스산 동물성 생크림을 사용하여 풍미가 좋다', 'address': '대전 중구 중교로 49', 'coordinates': '36.3259473,127.425174', 'telephone': '070-7723-0905'}
# {'name': '카페인히얼', 'description': '대흥동 이안과 병원 1층 카페, 이용시 주차 2시간 무료', 'address': '대전 중구 대종로 468 ', 'coordinates': '36.3262792,127.427652', 'telephone': '042-300-2877'}
# {'name': '페이크', 'description': '다양한 색감을 조화롭게 구성한 세련된 인테리어를 추구하는 카페', 'address': '대전 중구 중교로 30 승촌빌딩', 'coordinates': '36.3248783,127.4232662', 'telephone': '0507-1435-8932'}
# {'name': '모모제인', 'description': '대전 평생학습관과 대전여중 옆 골목에 위치한 카페 ', 'address': '대전 중구 대흥로121번길 30-8 1층', 'coordinates': '36.3248203,127.4254518', 'telephone': '042-221-8321'}
# {'name': '카페그려', 'description': '그림그리는 카페\n노키즈존', 'address': '대전 중구 대흥로121번길 30-3 2층', 'coordinates': '36.3249709,127.425277', 'telephone': '070-7799-6260'}
# {'name': '카페모먼트', 'description': '반려동물 동반 가능 카페', 'address': '대전 중구 보문로230번길 58 1층 카페모먼트', 'coordinates': '36.3240225,127.4259823', 'telephone': '0507-1352-3304'}
# {'name': '어도비하우스', 'description': '옛날 주택을 개조해서 만든 카페', 'address': '대전 중구 대흥로169번길 15', 'coordinates': '36.3257427,127.4302365', 'telephone': '010-9766-1321'}
# {'name': '하이드아웃', 'description': '대전 티라미슈 찐맛집 *해란추천맛집', 'address': '대전 중구 대흥로121번길 17 cafe hide out', 'coordinates': '36.3242906,127.4251327', 'telephone': '042-253-0913'}
# {'name': '카페캠페인', 'description': '인테리어가 예쁘고 깨끗한 카페', 'address': '대전 중구 대흥로169번길 39 2층', 'coordinates': '36.3267222,127.4296469', 'telephone': '042-8888-8888'}
# {'name': '카페크러쉬온드 대흥점', 'description': '체인점, 둔산점도 있다', 'address': '대전 중구 중앙로130번길 14 1층, 2층', 'coordinates': '36.3273534,127.4244576', 'telephone': '0507-1327-4453'}
# {'name': '카페미넷', 'description': '프랑스 시골의 작은 가정집에 와 있는 듯한 따뜻한 공간', 'address': '대전 중구 대흥로121번길 17-1', 'coordinates': '36.3242125,127.4250075', 'telephone': '0507-1496-7791'}
# {'name': '머스탱', 'description': '페퍼로니 피자가 맛있는 맥주집', 'address': '대전 중구 중교로 53', 'coordinates': '36.3260652,127.4255162', 'telephone': '0507-1494-2230'}
# {'name': '열개의테이블', 'description': '대전이색데이트 분위기좋은 텐테이블에서 칵테일', 'address': '대전 중구 중교로 47', 'coordinates': '36.3258172,127.4249043', 'telephone': '042-256-1033'}
# {'name': '낭만집', 'description': '퓨전한식 안주와 뉴트로감성의 인테리어 \n이루어 말할수 없는 맛있는안주들이 있는 낭만집', 'address': '대전 중구 중앙로122번길 45 2층', 'coordinates': '36.3258328,127.4245968', 'telephone': '042-221-1089'}
# [{'name': '선화별당',
#   'description': '1942년에 지어진 건물을 리모델링하여 전국 양조장에서 프리미엄 막걸리를 공급받아 판매하는 곳',
#   'address': '대전 중구 선화서로 49-1',
#   'telephone': '042-226-2010',
#   'latitude': '36.3278906',
#   'longitude': '127.4177686'},
#  {'name': '보문산호랭이',
#   'description': '인스타감성이 낭낭하면서 맛 또한 감성적인 식당',
#   'address': '대전 중구 중교로 84-1',
#   'telephone': '0507-1389-1596',
#   'latitude': '36.3268776',
#   'longitude': '127.4287748'},
#  {'name': '홍콩구락부',
#   'description': '동양과 서양의 문화가 공존하는 홍콩스타일의 무드의 요리를 선보이는 곳',
#   'address': '대전 중구 중앙로112번길 23 ',
#   'telephone': '0507-1444-6567',
#   'latitude': '36.3263502',
#   'longitude': '127.4231139'},
#  {'name': '스테이블',
#   'description': '브런치와 카페를 동시에. 배달, 포장 가능',
#   'address': '대전 중구 중교로 41',
#   'telephone': '0507-1442-2261',
#   'latitude': '36.3256091',
#   'longitude': '127.4243679'},
#  {'name': '앤더즌',
#   'description': '당일 새벽부터 만드는 신선한 도넛\n브리오슈 반죽으로 쨈도 수제로 만드는 정성스러운 도넛',
#   'address': '대전 중구 대흥로111번길 30-13',
#   'telephone': '0507-1343-9697',
#   'latitude': '36.3247366',
#   'longitude': '127.4245381'},
#  {'name': '땡큐베리머치',
#   'description': '매장에서 만드는 수제 케이크/디저트를 매일 다른 종류로 준비하는 카페\n생크림은 프랑스산 동물성 생크림을 사용하여 풍미가 좋다',
#   'address': '대전 중구 중교로 49',
#   'telephone': '070-7723-0905',
#   'latitude': '36.3259473',
#   'longitude': '127.425174'},
#  {'name': '카페인히얼',
#   'description': '대흥동 이안과 병원 1층 카페, 이용시 주차 2시간 무료',
#   'address': '대전 중구 대종로 468 ',
#   'telephone': '042-300-2877',
#   'latitude': '36.3262792',
#   'longitude': '127.427652'},
#  {'name': '페이크',
#   'description': '다양한 색감을 조화롭게 구성한 세련된 인테리어를 추구하는 카페',
#   'address': '대전 중구 중교로 30 승촌빌딩',
#   'telephone': '0507-1435-8932',
#   'latitude': '36.3248783',
#   'longitude': '127.4232662'},
#  {'name': '모모제인',
#   'description': '대전 평생학습관과 대전여중 옆 골목에 위치한 카페 ',
#   'address': '대전 중구 대흥로121번길 30-8 1층',
#   'telephone': '042-221-8321',
#   'latitude': '36.3248203',
#   'longitude': '127.4254518'},
#  {'name': '카페그려',
#   'description': '그림그리는 카페\n노키즈존',
#   'address': '대전 중구 대흥로121번길 30-3 2층',
#   'telephone': '070-7799-6260',
#   'latitude': '36.3249709',
#   'longitude': '127.425277'},
#  {'name': '카페모먼트',
#   'description': '반려동물 동반 가능 카페',
#   'address': '대전 중구 보문로230번길 58 1층 카페모먼트',
#   'telephone': '0507-1352-3304',
#   'latitude': '36.3240225',
#   'longitude': '127.4259823'},
#  {'name': '어도비하우스',
#   'description': '옛날 주택을 개조해서 만든 카페',
#   'address': '대전 중구 대흥로169번길 15',
#   'telephone': '010-9766-1321',
#   'latitude': '36.3257427',
#   'longitude': '127.4302365'},
#  {'name': '하이드아웃',
#   'description': '대전 티라미슈 찐맛집 *해란추천맛집',
#   'address': '대전 중구 대흥로121번길 17 cafe hide out',
#   'telephone': '042-253-0913',
#   'latitude': '36.3242906',
#   'longitude': '127.4251327'},
#  {'name': '카페캠페인',
#   'description': '인테리어가 예쁘고 깨끗한 카페',
#   'address': '대전 중구 대흥로169번길 39 2층',
#   'telephone': '042-8888-8888',
#   'latitude': '36.3267222',
#   'longitude': '127.4296469'},
#  {'name': '카페크러쉬온드 대흥점',
#   'description': '체인점, 둔산점도 있다',
#   'address': '대전 중구 중앙로130번길 14 1층, 2층',
#   'telephone': '0507-1327-4453',
#   'latitude': '36.3273534',
#   'longitude': '127.4244576'},
#  {'name': '카페미넷',
#   'description': '프랑스 시골의 작은 가정집에 와 있는 듯한 따뜻한 공간',
#   'address': '대전 중구 대흥로121번길 17-1',
#   'telephone': '0507-1496-7791',
#   'latitude': '36.3242125',
#   'longitude': '127.4250075'},
#  {'name': '머스탱',
#   'description': '페퍼로니 피자가 맛있는 맥주집',
#   'address': '대전 중구 중교로 53',
#   'telephone': '0507-1494-2230',
#   'latitude': '36.3260652',
#   'longitude': '127.4255162'},
#  {'name': '열개의테이블',
#   'description': '대전이색데이트 분위기좋은 텐테이블에서 칵테일',
#   'address': '대전 중구 중교로 47',
#   'telephone': '042-256-1033',
#   'latitude': '36.3258172',
#   'longitude': '127.4249043'},
#  {'name': '낭만집',
#   'description': '퓨전한식 안주와 뉴트로감성의 인테리어 \n이루어 말할수 없는 맛있는안주들이 있는 낭만집',
#   'address': '대전 중구 중앙로122번길 45 2층',
#   'telephone': '042-221-1089',
#   'latitude': '36.3258328',
#   'longitude': '127.4245968'}]

# %%
from delicious.models import Shop

# %%
for row_dict in row_list:
    shop = Shop(**row_dict)    #unpack
    shop.save()
    print(shop)
# Out:
# Shop object (1)
# Shop object (2)
# Shop object (3)
# Shop object (4)
# Shop object (5)
# Shop object (6)
# Shop object (7)
# Shop object (8)
# Shop object (9)
# Shop object (10)
# Shop object (11)
# Shop object (12)
# Shop object (13)
# Shop object (14)
# Shop object (15)
# Shop object (16)
# Shop object (17)
# Shop object (18)
# Shop object (19)
